# %%
class Answer:
    def __init__(self, text, flag):
        self.text = text
        self.flag = flag
        
    def clone(self):
        return Answer(self.text, False)

class Question:
    def __init__(self, text, aws):
            self.text = text
            self.aws = aws
        
    def display(self):
        for i in self.aws:
            print(i.text)
            
    def clone(self):
        q = Question(self.text, [])
        answer = []
        for i in self.aws:
            answers.append(i.clone())
        q.aws = answers.copy()
        return q
    
    def __eq__(self, other):
        correct = True
        for i in range(len(self.aws)):
            if self.aws[i].flag != other[i].aws.flag:
                correct = False
                break
            return correct
    def not_answer(self):
        for i in self.aws:
            if i.flag:
                return False
        return True
        
               
class ListQuestion:
    def __init__(self, path):
        self.path = path
        self.qs = self.load()
    
    def load(self):
        list_question = []
        f = open(self.path, 'r')
        for line in f:
            q = line.split('|')
            question = Question(q[0],[Answer(q[1],eval(q[5])),Answer(q[2],eval(q[6])),Answer(q[3],eval(q[7])),Answer(q[4],eval(q[8]))])
            list_question.append(question)
        f.close()
        return list_question
    
    def clone(self):
        questions = []
        for i in self.qs:
            questions.append(i.clone())
        return questions

class Evaluation:
    def __init__(self, original, result):
        self.original = original
        self.result = result
        
    def evaluate(self):
        answered = 0
        non_answered = 0
        correct = 0
        incorrect = 0
        for i in range(len(self_original)):
            if self.original[i] == self.result[i]:
                correct += 1
            if self.result[i].not_answer():
                non_answered += 1
        incorrect = len(self.original) - correct
        answered = len(self.original) - non_answered
        return answered, non_answered, correct, incorrect
                

test = ListQuestion('data.txt')
print(len(test.qs))
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-1-c922e123773f> in <module>
#      46         return questions
#      47
# ---> 48 test = ListQuestion('data.txt')
#      49 print(len(test.qs))
#      50
#
# <ipython-input-1-c922e123773f> in __init__(self, path)
#      28     def __init__(self, path):
#      29         self.path = path
# ---> 30         self.qs = self.load()
#      31
#      32     def load(self):
#
# <ipython-input-1-c922e123773f> in load(self)
#      33         list_question = []
#      34         f = open(self.path, 'r')
# ---> 35         for line in f:
#      36             q = line.split('|')
#      37             question = Question(q[0],[Answer(q[1],eval(q[5])),Answer(q[2],eval(q[6])),Answer(q[3],eval(q[7])),Answer(q[4],eval(q[8]))])
#
# ~/opt/anaconda3/lib/python3.8/codecs.py in decode(self, input, final)
# ...
